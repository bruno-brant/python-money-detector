# %% [markdown]
# # Initialize pytorch

# %%
# Train torchvision with our dataset:
# https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html
# https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html

from __future__ import print_function
from __future__ import division

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import json

# Torch enable cuda
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print("=======================================================================")
print(" PyTorch version:     ", torch.__version__)
print(" Torchvision version: ", torchvision.__version__)
print(" Device:              ", device)
print("=======================================================================")
# Out:
# =======================================================================
#  PyTorch version:      1.12.1+cu116
#  Torchvision version:  0.13.1+cu116
#  Device:               cuda:0
# =======================================================================

# %% [markdown]
# # Constants

# %%
ASSETS_DIR = '../assets'
DATASET_DIR = f'{ASSETS_DIR}/coins_dataset'
MODEL_STATE_DIR = f'../model_state'

# %% [markdown]
# # Create DataLoaders

# %%
from money_counter.data import get_data_loaders

# Get the data loaders
data_loader_train, data_loader_test = get_data_loaders(DATASET_DIR)

# %% [markdown]
# # Construct Model

# %%
import money_counter.models

model, model_name = money_counter.models.get_fasterrcnn_pretrained()

# %% [markdown]
# # Train!

# %%
from money_counter.training import train

train(model, model_name, data_loader_train, data_loader_test,
      device=device, state_dir=MODEL_STATE_DIR, print_frequency=25, num_epochs=100)
# Out:
# Loading model from ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_9.pth
# Loaded model from ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_9.pth
# Starting training from epoch '9' with loss = '0.46978312043043285'.
# Epoch: [9]  [ 0/26]  eta: 0:02:14  lr: 0.000005  loss: 0.4639 (0.4639)  loss_classifier: 0.3246 (0.3246)  loss_box_reg: 0.1312 (0.1312)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0072 (0.0072)  time: 5.1703  data: 0.9438  max mem: 4705
# Epoch: [9]  [25/26]  eta: 0:00:02  lr: 0.000005  loss: 0.4477 (0.4655)  loss_classifier: 0.2896 (0.3022)  loss_box_reg: 0.1498 (0.1526)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0083 (0.0094)  time: 2.0971  data: 0.8211  max mem: 6158
# Epoch: [9] Total time: 0:00:59 (2.2794 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_9.pth
# Backuping model file at epoch "{epoch}"...
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_9.pth
# Epoch: [10]  [ 0/26]  eta: 0:00:55  lr: 0.000005  loss: 0.4408 (0.4408)  loss_classifier: 0.2761 (0.2761)  loss_box_reg: 0.1516 (0.1516)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0121 (0.0121)  time: 2.1485  data: 0.6882  max mem: 6158
# Epoch: [10]  [25/26]  eta: 0:00:02  lr: 0.000005  loss: 0.4652 (0.4692)  loss_classifier: 0.3041 (0.3046)  loss_box_reg: 0.1527 (0.1538)  loss_objectness: 0.0012 (0.0014)  loss_rpn_box_reg: 0.0073 (0.0095)  time: 2.0580  data: 0.7630  max mem: 6158
# Epoch: [10] Total time: 0:00:54 (2.0825 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_10.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_10.pth
# Epoch: [11]  [ 0/26]  eta: 0:00:56  lr: 0.000005  loss: 0.3473 (0.3473)  loss_classifier: 0.2439 (0.2439)  loss_box_reg: 0.1005 (0.1005)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 2.1865  data: 0.7202  max mem: 6158
# Epoch: [11]  [25/26]  eta: 0:00:02  lr: 0.000005  loss: 0.4698 (0.4710)  loss_classifier: 0.3026 (0.3069)  loss_box_reg: 0.1547 (0.1534)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0092 (0.0094)  time: 2.0464  data: 0.7477  max mem: 6158
# Epoch: [11] Total time: 0:00:54 (2.0786 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_11.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_11.pth
# Epoch: [12]  [ 0/26]  eta: 0:00:56  lr: 0.000000  loss: 0.4480 (0.4480)  loss_classifier: 0.2900 (0.2900)  loss_box_reg: 0.1513 (0.1513)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0061 (0.0061)  time: 2.1745  data: 0.7282  max mem: 6158
# Epoch: [12]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4804 (0.4729)  loss_classifier: 0.3157 (0.3080)  loss_box_reg: 0.1461 (0.1541)  loss_objectness: 0.0012 (0.0015)  loss_rpn_box_reg: 0.0097 (0.0094)  time: 2.0948  data: 0.7635  max mem: 6158
# Epoch: [12] Total time: 0:00:55 (2.1257 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_12.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_12.pth
# Epoch: [13]  [ 0/26]  eta: 0:00:57  lr: 0.000000  loss: 0.5363 (0.5363)  loss_classifier: 0.3381 (0.3381)  loss_box_reg: 0.1833 (0.1833)  loss_objectness: 0.0027 (0.0027)  loss_rpn_box_reg: 0.0122 (0.0122)  time: 2.1935  data: 0.7332  max mem: 6158
# Epoch: [13]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4608 (0.4638)  loss_classifier: 0.3058 (0.3002)  loss_box_reg: 0.1446 (0.1530)  loss_objectness: 0.0009 (0.0014)  loss_rpn_box_reg: 0.0078 (0.0093)  time: 2.0654  data: 0.7548  max mem: 6158
# Epoch: [13] Total time: 0:00:53 (2.0761 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_13.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_13.pth
# Epoch: [14]  [ 0/26]  eta: 0:00:57  lr: 0.000000  loss: 0.4904 (0.4904)  loss_classifier: 0.3090 (0.3090)  loss_box_reg: 0.1711 (0.1711)  loss_objectness: 0.0015 (0.0015)  loss_rpn_box_reg: 0.0088 (0.0088)  time: 2.2015  data: 0.7482  max mem: 6158
# Epoch: [14]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4626 (0.4688)  loss_classifier: 0.2989 (0.3027)  loss_box_reg: 0.1462 (0.1537)  loss_objectness: 0.0012 (0.0031)  loss_rpn_box_reg: 0.0090 (0.0093)  time: 2.0117  data: 0.7716  max mem: 6158
# Epoch: [14] Total time: 0:00:53 (2.0487 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_14.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_14.pth
# Epoch: [15]  [ 0/26]  eta: 0:00:57  lr: 0.000000  loss: 0.4239 (0.4239)  loss_classifier: 0.2799 (0.2799)  loss_box_reg: 0.1383 (0.1383)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0050 (0.0050)  time: 2.2165  data: 0.7322  max mem: 6158
# Epoch: [15]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4693 (0.4678)  loss_classifier: 0.3062 (0.3031)  loss_box_reg: 0.1623 (0.1538)  loss_objectness: 0.0012 (0.0016)  loss_rpn_box_reg: 0.0089 (0.0093)  time: 2.0578  data: 0.7843  max mem: 6158
# Epoch: [15] Total time: 0:00:53 (2.0739 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_15.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_15.pth
# Epoch: [16]  [ 0/26]  eta: 0:00:57  lr: 0.000000  loss: 0.3634 (0.3634)  loss_classifier: 0.2473 (0.2473)  loss_box_reg: 0.1054 (0.1054)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0103 (0.0103)  time: 2.1995  data: 0.7272  max mem: 6158
# Epoch: [16]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4811 (0.4754)  loss_classifier: 0.3045 (0.3085)  loss_box_reg: 0.1568 (0.1559)  loss_objectness: 0.0012 (0.0017)  loss_rpn_box_reg: 0.0085 (0.0093)  time: 2.0199  data: 0.7632  max mem: 6158
# Epoch: [16] Total time: 0:00:52 (2.0307 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_16.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_16.pth
# Epoch: [17]  [ 0/26]  eta: 0:00:59  lr: 0.000000  loss: 0.4488 (0.4488)  loss_classifier: 0.2884 (0.2884)  loss_box_reg: 0.1503 (0.1503)  loss_objectness: 0.0017 (0.0017)  loss_rpn_box_reg: 0.0084 (0.0084)  time: 2.3015  data: 0.8092  max mem: 6158
# Epoch: [17]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4565 (0.4676)  loss_classifier: 0.2960 (0.3043)  loss_box_reg: 0.1464 (0.1525)  loss_objectness: 0.0011 (0.0015)  loss_rpn_box_reg: 0.0079 (0.0092)  time: 2.0228  data: 0.7600  max mem: 6158
# Epoch: [17] Total time: 0:00:52 (2.0242 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_17.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_17.pth
# Epoch: [18]  [ 0/26]  eta: 0:00:58  lr: 0.000000  loss: 0.4437 (0.4437)  loss_classifier: 0.2817 (0.2817)  loss_box_reg: 0.1519 (0.1519)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0088 (0.0088)  time: 2.2515  data: 0.7512  max mem: 6158
# Epoch: [18]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4660 (0.4685)  loss_classifier: 0.2965 (0.3027)  loss_box_reg: 0.1513 (0.1546)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0084 (0.0094)  time: 2.0336  data: 0.7645  max mem: 6158
# Epoch: [18] Total time: 0:00:53 (2.0563 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_18.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_18.pth
# Epoch: [19]  [ 0/26]  eta: 0:00:49  lr: 0.000000  loss: 0.2633 (0.2633)  loss_classifier: 0.1852 (0.1852)  loss_box_reg: 0.0758 (0.0758)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 1.9134  data: 0.8192  max mem: 6158
# Epoch: [19]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4748 (0.4719)  loss_classifier: 0.3155 (0.3078)  loss_box_reg: 0.1575 (0.1533)  loss_objectness: 0.0013 (0.0015)  loss_rpn_box_reg: 0.0093 (0.0094)  time: 2.0308  data: 0.7799  max mem: 6158
# Epoch: [19] Total time: 0:00:53 (2.0493 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_19.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_19.pth
# Epoch: [20]  [ 0/26]  eta: 0:00:59  lr: 0.000000  loss: 0.4932 (0.4932)  loss_classifier: 0.3479 (0.3479)  loss_box_reg: 0.1372 (0.1372)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 2.2780  data: 0.7902  max mem: 6158
# Epoch: [20]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4743 (0.4710)  loss_classifier: 0.2980 (0.3057)  loss_box_reg: 0.1590 (0.1543)  loss_objectness: 0.0011 (0.0015)  loss_rpn_box_reg: 0.0087 (0.0095)  time: 2.0738  data: 0.7688  max mem: 6158
# Epoch: [20] Total time: 0:00:54 (2.0907 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_20.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_20.pth
# Epoch: [21]  [ 0/26]  eta: 0:00:57  lr: 0.000000  loss: 0.5116 (0.5116)  loss_classifier: 0.3085 (0.3085)  loss_box_reg: 0.1867 (0.1867)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0159 (0.0159)  time: 2.2285  data: 0.7502  max mem: 6158
# Epoch: [21]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4664 (0.4671)  loss_classifier: 0.3124 (0.3028)  loss_box_reg: 0.1484 (0.1537)  loss_objectness: 0.0012 (0.0013)  loss_rpn_box_reg: 0.0079 (0.0093)  time: 1.9930  data: 0.7625  max mem: 6158
# Epoch: [21] Total time: 0:00:52 (2.0360 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_21.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_21.pth
# Epoch: [22]  [ 0/26]  eta: 0:00:46  lr: 0.000000  loss: 0.4577 (0.4577)  loss_classifier: 0.2736 (0.2736)  loss_box_reg: 0.1722 (0.1722)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0113 (0.0113)  time: 1.7784  data: 0.6702  max mem: 6158
# Epoch: [22]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4867 (0.4704)  loss_classifier: 0.3063 (0.3050)  loss_box_reg: 0.1540 (0.1545)  loss_objectness: 0.0014 (0.0016)  loss_rpn_box_reg: 0.0088 (0.0093)  time: 2.0051  data: 0.7761  max mem: 6158
# Epoch: [22] Total time: 0:00:52 (2.0323 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_22.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_22.pth
# Epoch: [23]  [ 0/26]  eta: 0:00:48  lr: 0.000000  loss: 0.4660 (0.4660)  loss_classifier: 0.3205 (0.3205)  loss_box_reg: 0.1341 (0.1341)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0105 (0.0105)  time: 1.8704  data: 0.7622  max mem: 6158
# Epoch: [23]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4627 (0.4685)  loss_classifier: 0.2912 (0.3040)  loss_box_reg: 0.1473 (0.1538)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0086 (0.0093)  time: 2.0542  data: 0.7659  max mem: 6158
# Epoch: [23] Total time: 0:00:53 (2.0717 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_23.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_23.pth
# Epoch: [24]  [ 0/26]  eta: 0:00:48  lr: 0.000000  loss: 0.4959 (0.4959)  loss_classifier: 0.3240 (0.3240)  loss_box_reg: 0.1597 (0.1597)  loss_objectness: 0.0018 (0.0018)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 1.8674  data: 0.7602  max mem: 6158
# Epoch: [24]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4852 (0.4730)  loss_classifier: 0.3129 (0.3072)  loss_box_reg: 0.1483 (0.1551)  loss_objectness: 0.0009 (0.0015)  loss_rpn_box_reg: 0.0075 (0.0092)  time: 2.0090  data: 0.7654  max mem: 6158
# Epoch: [24] Total time: 0:00:52 (2.0243 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_24.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_24.pth
# Epoch: [25]  [ 0/26]  eta: 0:00:58  lr: 0.000000  loss: 0.5385 (0.5385)  loss_classifier: 0.3182 (0.3182)  loss_box_reg: 0.2033 (0.2033)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0151 (0.0151)  time: 2.2505  data: 0.7672  max mem: 6158
# Epoch: [25]  [25/26]  eta: 0:00:02  lr: 0.000000  loss: 0.4877 (0.4714)  loss_classifier: 0.3063 (0.3053)  loss_box_reg: 0.1567 (0.1556)  loss_objectness: 0.0011 (0.0013)  loss_rpn_box_reg: 0.0086 (0.0093)  time: 2.0247  data: 0.7926  max mem: 6158
# Epoch: [25] Total time: 0:00:53 (2.0636 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_25.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_25.pth
# Epoch: [26]  [ 0/26]  eta: 0:00:45  lr: 0.000000  loss: 0.4416 (0.4416)  loss_classifier: 0.3072 (0.3072)  loss_box_reg: 0.1275 (0.1275)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0063 (0.0063)  time: 1.7504  data: 0.7892  max mem: 6158
# Epoch: [26]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4717 (0.4682)  loss_classifier: 0.3084 (0.3036)  loss_box_reg: 0.1622 (0.1538)  loss_objectness: 0.0012 (0.0014)  loss_rpn_box_reg: 0.0099 (0.0094)  time: 1.9294  data: 0.7692  max mem: 6158
# Epoch: [26] Total time: 0:00:50 (1.9306 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_26.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_26.pth
# Epoch: [27]  [ 0/26]  eta: 0:00:46  lr: 0.000000  loss: 0.5210 (0.5210)  loss_classifier: 0.3312 (0.3312)  loss_box_reg: 0.1753 (0.1753)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0127 (0.0127)  time: 1.7804  data: 0.8002  max mem: 6158
# Epoch: [27]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4673 (0.4687)  loss_classifier: 0.3095 (0.3049)  loss_box_reg: 0.1457 (0.1528)  loss_objectness: 0.0012 (0.0017)  loss_rpn_box_reg: 0.0096 (0.0093)  time: 1.9336  data: 0.7778  max mem: 6158
# Epoch: [27] Total time: 0:00:50 (1.9581 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_27.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_27.pth
# Epoch: [28]  [ 0/26]  eta: 0:00:53  lr: 0.000000  loss: 0.4901 (0.4901)  loss_classifier: 0.3406 (0.3406)  loss_box_reg: 0.1397 (0.1397)  loss_objectness: 0.0032 (0.0032)  loss_rpn_box_reg: 0.0067 (0.0067)  time: 2.0625  data: 0.7532  max mem: 6158
# Epoch: [28]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4670 (0.4693)  loss_classifier: 0.2880 (0.3041)  loss_box_reg: 0.1441 (0.1542)  loss_objectness: 0.0013 (0.0015)  loss_rpn_box_reg: 0.0096 (0.0094)  time: 1.9457  data: 0.7723  max mem: 6158
# Epoch: [28] Total time: 0:00:51 (1.9722 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_28.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_28.pth
# Epoch: [29]  [ 0/26]  eta: 0:00:47  lr: 0.000000  loss: 0.5878 (0.5878)  loss_classifier: 0.3749 (0.3749)  loss_box_reg: 0.1959 (0.1959)  loss_objectness: 0.0022 (0.0022)  loss_rpn_box_reg: 0.0148 (0.0148)  time: 1.8094  data: 0.8362  max mem: 6158
# Epoch: [29]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4546 (0.4721)  loss_classifier: 0.2911 (0.3053)  loss_box_reg: 0.1505 (0.1558)  loss_objectness: 0.0014 (0.0015)  loss_rpn_box_reg: 0.0082 (0.0095)  time: 1.9284  data: 0.7602  max mem: 6158
# Epoch: [29] Total time: 0:00:50 (1.9421 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_29.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_29.pth
# Epoch: [30]  [ 0/26]  eta: 0:00:55  lr: 0.000000  loss: 0.3857 (0.3857)  loss_classifier: 0.2623 (0.2623)  loss_box_reg: 0.1172 (0.1172)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0054 (0.0054)  time: 2.1165  data: 0.8022  max mem: 6158
# Epoch: [30]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4734 (0.4656)  loss_classifier: 0.3147 (0.3020)  loss_box_reg: 0.1410 (0.1532)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0074 (0.0093)  time: 1.9520  data: 0.7650  max mem: 6158
# Epoch: [30] Total time: 0:00:51 (1.9728 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_30.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_30.pth
# Epoch: [31]  [ 0/26]  eta: 0:00:53  lr: 0.000000  loss: 0.3569 (0.3569)  loss_classifier: 0.2462 (0.2462)  loss_box_reg: 0.1066 (0.1066)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 2.0765  data: 0.7712  max mem: 6158
# Epoch: [31]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4730 (0.4659)  loss_classifier: 0.3028 (0.3007)  loss_box_reg: 0.1548 (0.1540)  loss_objectness: 0.0010 (0.0016)  loss_rpn_box_reg: 0.0096 (0.0096)  time: 1.9406  data: 0.7643  max mem: 6158
# Epoch: [31] Total time: 0:00:50 (1.9320 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_31.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_31.pth
# Epoch: [32]  [ 0/26]  eta: 0:00:52  lr: 0.000000  loss: 0.4398 (0.4398)  loss_classifier: 0.2760 (0.2760)  loss_box_reg: 0.1479 (0.1479)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0148 (0.0148)  time: 2.0275  data: 0.7192  max mem: 6158
# Epoch: [32]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4787 (0.4695)  loss_classifier: 0.3063 (0.3038)  loss_box_reg: 0.1509 (0.1548)  loss_objectness: 0.0012 (0.0015)  loss_rpn_box_reg: 0.0088 (0.0093)  time: 1.9581  data: 0.7781  max mem: 6158
# Epoch: [32] Total time: 0:00:51 (1.9654 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_32.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_32.pth
# Epoch: [33]  [ 0/26]  eta: 0:00:54  lr: 0.000000  loss: 0.4909 (0.4909)  loss_classifier: 0.3368 (0.3368)  loss_box_reg: 0.1477 (0.1477)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 2.0955  data: 0.7812  max mem: 6158
# Epoch: [33]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4753 (0.4702)  loss_classifier: 0.3071 (0.3059)  loss_box_reg: 0.1501 (0.1533)  loss_objectness: 0.0012 (0.0016)  loss_rpn_box_reg: 0.0090 (0.0095)  time: 1.9432  data: 0.7551  max mem: 6158
# Epoch: [33] Total time: 0:00:50 (1.9571 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_33.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_33.pth
# Epoch: [34]  [ 0/26]  eta: 0:00:44  lr: 0.000000  loss: 0.4727 (0.4727)  loss_classifier: 0.3035 (0.3035)  loss_box_reg: 0.1536 (0.1536)  loss_objectness: 0.0017 (0.0017)  loss_rpn_box_reg: 0.0139 (0.0139)  time: 1.7194  data: 0.7492  max mem: 6158
# Epoch: [34]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4631 (0.4645)  loss_classifier: 0.2971 (0.3008)  loss_box_reg: 0.1463 (0.1530)  loss_objectness: 0.0008 (0.0014)  loss_rpn_box_reg: 0.0093 (0.0093)  time: 1.9542  data: 0.7722  max mem: 6158
# Epoch: [34] Total time: 0:00:51 (1.9746 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_34.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_34.pth
# Epoch: [35]  [ 0/26]  eta: 0:00:53  lr: 0.000000  loss: 0.5641 (0.5641)  loss_classifier: 0.3471 (0.3471)  loss_box_reg: 0.1989 (0.1989)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0157 (0.0157)  time: 2.0575  data: 0.7432  max mem: 6158
# Epoch: [35]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4509 (0.4720)  loss_classifier: 0.2979 (0.3052)  loss_box_reg: 0.1505 (0.1559)  loss_objectness: 0.0010 (0.0016)  loss_rpn_box_reg: 0.0080 (0.0093)  time: 1.9401  data: 0.7689  max mem: 6158
# Epoch: [35] Total time: 0:00:51 (1.9651 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_35.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_35.pth
# Epoch: [36]  [ 0/26]  eta: 0:00:46  lr: 0.000000  loss: 0.4749 (0.4749)  loss_classifier: 0.3205 (0.3205)  loss_box_reg: 0.1467 (0.1467)  loss_objectness: 0.0018 (0.0018)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 1.7754  data: 0.7982  max mem: 6158
# Epoch: [36]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4440 (0.4693)  loss_classifier: 0.2840 (0.3046)  loss_box_reg: 0.1532 (0.1540)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0084 (0.0094)  time: 1.9478  data: 0.7697  max mem: 6158
# Epoch: [36] Total time: 0:00:50 (1.9519 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_36.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_36.pth
# Epoch: [37]  [ 0/26]  eta: 0:00:45  lr: 0.000000  loss: 0.3612 (0.3612)  loss_classifier: 0.2242 (0.2242)  loss_box_reg: 0.1278 (0.1278)  loss_objectness: 0.0038 (0.0038)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 1.7344  data: 0.7692  max mem: 6158
# Epoch: [37]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4709 (0.4692)  loss_classifier: 0.2990 (0.3049)  loss_box_reg: 0.1572 (0.1534)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0084 (0.0094)  time: 1.9557  data: 0.7682  max mem: 6158
# Epoch: [37] Total time: 0:00:50 (1.9520 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_37.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_37.pth
# Epoch: [38]  [ 0/26]  eta: 0:00:53  lr: 0.000000  loss: 0.4443 (0.4443)  loss_classifier: 0.2689 (0.2689)  loss_box_reg: 0.1648 (0.1648)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0096 (0.0096)  time: 2.0665  data: 0.7572  max mem: 6158
# Epoch: [38]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4576 (0.4705)  loss_classifier: 0.3023 (0.3059)  loss_box_reg: 0.1365 (0.1535)  loss_objectness: 0.0012 (0.0016)  loss_rpn_box_reg: 0.0077 (0.0094)  time: 1.9275  data: 0.7561  max mem: 6158
# Epoch: [38] Total time: 0:00:50 (1.9582 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_38.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_38.pth
# Epoch: [39]  [ 0/26]  eta: 0:00:52  lr: 0.000000  loss: 0.4658 (0.4658)  loss_classifier: 0.2981 (0.2981)  loss_box_reg: 0.1553 (0.1553)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0115 (0.0115)  time: 2.0025  data: 0.7012  max mem: 6158
# Epoch: [39]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4682 (0.4678)  loss_classifier: 0.3084 (0.3025)  loss_box_reg: 0.1499 (0.1543)  loss_objectness: 0.0011 (0.0016)  loss_rpn_box_reg: 0.0079 (0.0093)  time: 1.9411  data: 0.7688  max mem: 6158
# Epoch: [39] Total time: 0:00:50 (1.9531 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_39.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_39.pth
# Epoch: [40]  [ 0/26]  eta: 0:00:46  lr: 0.000000  loss: 0.5017 (0.5017)  loss_classifier: 0.3407 (0.3407)  loss_box_reg: 0.1512 (0.1512)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0084 (0.0084)  time: 1.7874  data: 0.8142  max mem: 6158
# Epoch: [40]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4561 (0.4703)  loss_classifier: 0.2951 (0.3017)  loss_box_reg: 0.1600 (0.1573)  loss_objectness: 0.0012 (0.0016)  loss_rpn_box_reg: 0.0095 (0.0097)  time: 1.9234  data: 0.7539  max mem: 6158
# Epoch: [40] Total time: 0:00:50 (1.9268 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_40.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_40.pth
# Epoch: [41]  [ 0/26]  eta: 0:00:53  lr: 0.000000  loss: 0.3447 (0.3447)  loss_classifier: 0.2347 (0.2347)  loss_box_reg: 0.1054 (0.1054)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 2.0455  data: 0.7512  max mem: 6158
# Epoch: [41]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4728 (0.4678)  loss_classifier: 0.3031 (0.3030)  loss_box_reg: 0.1503 (0.1538)  loss_objectness: 0.0013 (0.0017)  loss_rpn_box_reg: 0.0087 (0.0093)  time: 1.9493  data: 0.7710  max mem: 6158
# Epoch: [41] Total time: 0:00:51 (1.9658 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_41.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_41.pth
# Epoch: [42]  [ 0/26]  eta: 0:00:46  lr: 0.000000  loss: 0.5274 (0.5274)  loss_classifier: 0.3510 (0.3510)  loss_box_reg: 0.1638 (0.1638)  loss_objectness: 0.0014 (0.0014)  loss_rpn_box_reg: 0.0112 (0.0112)  time: 1.7974  data: 0.8162  max mem: 6158
# Epoch: [42]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4646 (0.4690)  loss_classifier: 0.3004 (0.3033)  loss_box_reg: 0.1532 (0.1541)  loss_objectness: 0.0015 (0.0022)  loss_rpn_box_reg: 0.0095 (0.0095)  time: 1.9566  data: 0.7613  max mem: 6158
# Epoch: [42] Total time: 0:00:50 (1.9401 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_42.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_42.pth
# Epoch: [43]  [ 0/26]  eta: 0:00:45  lr: 0.000000  loss: 0.4067 (0.4067)  loss_classifier: 0.2498 (0.2498)  loss_box_reg: 0.1491 (0.1491)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0069 (0.0069)  time: 1.7424  data: 0.7802  max mem: 6158
# Epoch: [43]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4599 (0.4644)  loss_classifier: 0.2991 (0.3003)  loss_box_reg: 0.1469 (0.1530)  loss_objectness: 0.0011 (0.0019)  loss_rpn_box_reg: 0.0075 (0.0092)  time: 1.9546  data: 0.7595  max mem: 6158
# Epoch: [43] Total time: 0:00:50 (1.9509 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_43.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_43.pth
# Epoch: [44]  [ 0/26]  eta: 0:00:46  lr: 0.000000  loss: 0.5502 (0.5502)  loss_classifier: 0.3589 (0.3589)  loss_box_reg: 0.1680 (0.1680)  loss_objectness: 0.0064 (0.0064)  loss_rpn_box_reg: 0.0169 (0.0169)  time: 1.7724  data: 0.7912  max mem: 6158
# Epoch: [44]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4647 (0.4689)  loss_classifier: 0.2951 (0.3041)  loss_box_reg: 0.1539 (0.1542)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0079 (0.0094)  time: 1.9455  data: 0.7683  max mem: 6158
# Epoch: [44] Total time: 0:00:50 (1.9562 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_44.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_44.pth
# Epoch: [45]  [ 0/26]  eta: 0:00:51  lr: 0.000000  loss: 0.3518 (0.3518)  loss_classifier: 0.2337 (0.2337)  loss_box_reg: 0.1136 (0.1136)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 1.9985  data: 0.6932  max mem: 6158
# Epoch: [45]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4856 (0.4704)  loss_classifier: 0.3106 (0.3047)  loss_box_reg: 0.1551 (0.1547)  loss_objectness: 0.0010 (0.0015)  loss_rpn_box_reg: 0.0086 (0.0094)  time: 1.9328  data: 0.7690  max mem: 6158
# Epoch: [45] Total time: 0:00:50 (1.9567 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_45.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_45.pth
# Epoch: [46]  [ 0/26]  eta: 0:00:45  lr: 0.000000  loss: 0.4398 (0.4398)  loss_classifier: 0.2959 (0.2959)  loss_box_reg: 0.1336 (0.1336)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0095 (0.0095)  time: 1.7534  data: 0.7742  max mem: 6158
# Epoch: [46]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4533 (0.4651)  loss_classifier: 0.2967 (0.3001)  loss_box_reg: 0.1489 (0.1542)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0086 (0.0094)  time: 1.9598  data: 0.7559  max mem: 6158
# Epoch: [46] Total time: 0:00:50 (1.9555 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_46.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_46.pth
# Epoch: [47]  [ 0/26]  eta: 0:00:54  lr: 0.000000  loss: 0.4899 (0.4899)  loss_classifier: 0.3079 (0.3079)  loss_box_reg: 0.1699 (0.1699)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0113 (0.0113)  time: 2.0905  data: 0.7822  max mem: 6158
# Epoch: [47]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4616 (0.4692)  loss_classifier: 0.3066 (0.3051)  loss_box_reg: 0.1431 (0.1534)  loss_objectness: 0.0013 (0.0015)  loss_rpn_box_reg: 0.0076 (0.0092)  time: 1.9446  data: 0.7734  max mem: 6158
# Epoch: [47] Total time: 0:00:50 (1.9558 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_47.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_47.pth
# Epoch: [48]  [ 0/26]  eta: 0:00:54  lr: 0.000000  loss: 0.4909 (0.4909)  loss_classifier: 0.3283 (0.3283)  loss_box_reg: 0.1505 (0.1505)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0113 (0.0113)  time: 2.1145  data: 0.7992  max mem: 6158
# Epoch: [48]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4796 (0.4724)  loss_classifier: 0.2991 (0.3062)  loss_box_reg: 0.1587 (0.1554)  loss_objectness: 0.0014 (0.0014)  loss_rpn_box_reg: 0.0084 (0.0094)  time: 1.9495  data: 0.7568  max mem: 6158
# Epoch: [48] Total time: 0:00:50 (1.9487 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_48.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_48.pth
# Epoch: [49]  [ 0/26]  eta: 0:00:54  lr: 0.000000  loss: 0.5239 (0.5239)  loss_classifier: 0.3444 (0.3444)  loss_box_reg: 0.1685 (0.1685)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0097 (0.0097)  time: 2.1045  data: 0.7942  max mem: 6158
# Epoch: [49]  [25/26]  eta: 0:01:49  lr: 0.000000  loss: 0.4585 (0.4621)  loss_classifier: 0.2941 (0.2979)  loss_box_reg: 0.1484 (0.1534)  loss_objectness: 0.0011 (0.0015)  loss_rpn_box_reg: 0.0078 (0.0093)  time: 2.1214  data: 0.8390  max mem: 6158
# Epoch: [49] Total time: 0:47:29 (109.5838 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_49.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_49.pth
# Epoch: [50]  [ 0/26]  eta: 0:00:44  lr: 0.000000  loss: 0.3600 (0.3600)  loss_classifier: 0.2369 (0.2369)  loss_box_reg: 0.1152 (0.1152)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 1.7134  data: 0.7472  max mem: 6158
# Epoch: [50]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4673 (0.4677)  loss_classifier: 0.2956 (0.3023)  loss_box_reg: 0.1459 (0.1545)  loss_objectness: 0.0011 (0.0015)  loss_rpn_box_reg: 0.0079 (0.0094)  time: 1.8988  data: 0.7687  max mem: 6158
# Epoch: [50] Total time: 0:00:49 (1.9070 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_50.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_50.pth
# Epoch: [51]  [ 0/26]  eta: 0:00:52  lr: 0.000000  loss: 0.4237 (0.4237)  loss_classifier: 0.2701 (0.2701)  loss_box_reg: 0.1452 (0.1452)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0076 (0.0076)  time: 2.0355  data: 0.7402  max mem: 6158
# Epoch: [51]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4619 (0.4695)  loss_classifier: 0.3053 (0.3031)  loss_box_reg: 0.1524 (0.1556)  loss_objectness: 0.0011 (0.0013)  loss_rpn_box_reg: 0.0087 (0.0095)  time: 1.9699  data: 0.7632  max mem: 6158
# Epoch: [51] Total time: 0:00:51 (1.9776 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_51.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_51.pth
# Epoch: [52]  [ 0/26]  eta: 0:00:53  lr: 0.000000  loss: 0.4390 (0.4390)  loss_classifier: 0.2839 (0.2839)  loss_box_reg: 0.1492 (0.1492)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0050 (0.0050)  time: 2.0605  data: 0.7552  max mem: 6158
# Epoch: [52]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4555 (0.4680)  loss_classifier: 0.3046 (0.3030)  loss_box_reg: 0.1488 (0.1543)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0090 (0.0095)  time: 1.9059  data: 0.7653  max mem: 6158
# Epoch: [52] Total time: 0:00:50 (1.9467 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_52.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_52.pth
# Epoch: [53]  [ 0/26]  eta: 0:00:52  lr: 0.000000  loss: 0.3381 (0.3381)  loss_classifier: 0.2295 (0.2295)  loss_box_reg: 0.1041 (0.1041)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 2.0105  data: 0.7172  max mem: 6158
# Epoch: [53]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4699 (0.4746)  loss_classifier: 0.3070 (0.3084)  loss_box_reg: 0.1496 (0.1547)  loss_objectness: 0.0013 (0.0018)  loss_rpn_box_reg: 0.0083 (0.0096)  time: 1.9006  data: 0.7839  max mem: 6158
# Epoch: [53] Total time: 0:00:50 (1.9354 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_53.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_53.pth
# Epoch: [54]  [ 0/26]  eta: 0:00:52  lr: 0.000000  loss: 0.3975 (0.3975)  loss_classifier: 0.2408 (0.2408)  loss_box_reg: 0.1491 (0.1491)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0072 (0.0072)  time: 2.0105  data: 0.7082  max mem: 6158
# Epoch: [54]  [25/26]  eta: 0:00:01  lr: 0.000000  loss: 0.4480 (0.4694)  loss_classifier: 0.2968 (0.3039)  loss_box_reg: 0.1507 (0.1544)  loss_objectness: 0.0013 (0.0016)  loss_rpn_box_reg: 0.0086 (0.0094)  time: 1.8929  data: 0.7757  max mem: 6158
# Epoch: [54] Total time: 0:00:50 (1.9242 s / it)
# Saving model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_54.pth
# Saved model to ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_54.pth
# Epoch: [55]  [ 0/26]  eta: 0:01:02  lr: 0.000000  loss: 0.4918 (0.4918)  loss_classifier: 0.3174 (0.3174)  loss_box_reg: 0.1626 (0.1626)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0112 (0.0112)  time: 2.4095  data: 0.7752  max mem: 6158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 3
#       1 from money_counter.training import train
# ----> 3 train(model, model_name, data_loader_train, data_loader_test,
#       4       device=device, state_dir=MODEL_STATE_DIR, print_frequency=25, num_epochs=100)
#
# File d:\OneDrive\Source\mba\15. TCC\src\money_counter\training.py:49, in train(model, model_name, data_loader_train, data_loader_test, num_epochs, device, version_manager, state_dir, evaluate, print_frequency)
#      45 print(f"Starting training from epoch '{epoch}' with loss = '{loss}'.")
#      47 while epoch < num_epochs:
#      48     # train for one epoch, printing every 10 iterations
# ---> 49     metric_logger = engine.train_one_epoch(model, optimizer, data_loader_train,
#      50                                     device, epoch, print_freq=print_frequency)
#      51     # update the learning rate
#      52     lr_scheduler.step()
#
# File d:\OneDrive\Source\mba\15. TCC\src\money_counter\engine.py:32, in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler)
#      27     warmup_iters = min(1000, len(data_loader) - 1)
#      29     lr_scheduler = torch.optim.lr_scheduler.LinearLR(
#      30         optimizer, start_factor=warmup_factor, total_iters=warmup_iters)
# ---> 32 for images, targets in metric_logger.log_every(data_loader, print_freq, header):
#      33     images = list(image.to(device) for image in images)
#      34     targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#
# File d:\OneDrive\Source\mba\15. TCC\src\money_counter\utils.py:211, in MetricLogger.log_every(self, iterable, print_freq, header)
#     202     log_msg = self.delimiter.join([
#     203         header,
#     204         '[{0' + space_fmt + '}/{1}]',
#    (...)
#     208         'data: {data}'
#     209     ])
#     210 MB = 1024.0 * 1024.0
# --> 211 for obj in iterable:
#     212     data_time.update(time.time() - end)
#     213     yield obj
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\torch\utils\data\dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\torch\utils\data\dataloader.py:721, in _SingleProcessDataLoaderIter._next_data(self)
#     719 def _next_data(self):
#     720     index = self._next_index()  # may raise StopIteration
# --> 721     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722     if self._pin_memory:
#     723         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\torch\utils\data\dataset.py:290, in Subset.__getitem__(self, idx)
#     288 if isinstance(idx, list):
#     289     return self.dataset[[self.indices[i] for i in idx]]
# --> 290 return self.dataset[self.indices[idx]]
#
# File d:\OneDrive\Source\mba\15. TCC\src\money_counter\data.py:138, in CoinsDataset.__getitem__(self, idx)
#     135 """Return the image and its metadata at the given index."""
#     136 filename = self._images_names[idx]
# --> 138 image = self._get_image(filename)
#     139 target = self._to_target(image.size, self._images_metadata[idx])
#     141 if self._transform:
#
# File d:\OneDrive\Source\mba\15. TCC\src\money_counter\data.py:204, in CoinsDataset._get_image(self, filename)
#     202 image_path = os.path.join(self._root_dir, filename)
#     203 image = Image.open(image_path)
# --> 204 image = ImageOps.exif_transpose(image)
#     205 image = image.convert('RGB')
#     207 return image
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\PIL\ImageOps.py:593, in exif_transpose(image)
#     583 method = {
#     584     2: Image.Transpose.FLIP_LEFT_RIGHT,
#     585     3: Image.Transpose.ROTATE_180,
#    (...)
#     590     8: Image.Transpose.ROTATE_90,
#     591 }.get(orientation)
#     592 if method is not None:
# --> 593     transposed_image = image.transpose(method)
#     594     transposed_exif = transposed_image.getexif()
#     595     if 0x0112 in transposed_exif:
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\PIL\Image.py:2688, in Image.transpose(self, method)
#    2674 def transpose(self, method):
#    2675     """
#    2676     Transpose image (flip or rotate in 90 degree steps)
#    2677
#    (...)
#    2685     :returns: Returns a flipped or rotated copy of this image.
#    2686     """
# -> 2688     self.load()
#    2689     return self._new(self.im.transpose(method))
#
# File d:\OneDrive\Source\mba\15. TCC\.venv\lib\site-packages\PIL\ImageFile.py:257, in ImageFile.load(self)
#     251         raise OSError(
#     252             "image file is truncated "
#     253             f"({len(b)} bytes not processed)"
#     254         )
#     256 b = b + s
# --> 257 n, err_code = decoder.decode(b)
#     258 if n < 0:
#     259     break
#
# KeyboardInterrupt:
