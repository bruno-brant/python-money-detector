# %%
import sys
if '..' not in sys.path:
    sys.path.append('..')

# %%
import os
import re
from typing import Any

import numpy as np
import pandas as pd
import reload
import torch
from torchmetrics.detection.mean_ap import MeanAveragePrecision

# %%
# %reload money_counter

from money_counter import data, engine, utils, coco_eval, models, constants
from money_counter.models import VersionManager
import money_counter.models
import money_counter.data
import money_counter

# %%
import logging

logging.basicConfig(level=logging.INFO)

# %%
MODEL_STATE_DIR = f'../model_state' # Relative to the notebook of the project
COINS_DATASET_PATH = os.environ['COINS_DATASET_PATH']

# %%
def add(df: pd.DataFrame, data) -> pd.DataFrame:
    last_idx = len(df)
    df.loc[last_idx] = data # type: ignore
    return df

# %%
def enumerate_states(model_state_dir, max=8):
    """
    Enumerates all the model states in the model_state_dir.
    :param model_state_dir: The directory where the model states are stored.
    :param max: The maximum number of model states to enumerate.
    :return: A generator of tuples (model name, epoch number, full path)
    """
    for model_name in os.listdir(model_state_dir):
        how_many = 0
        model_dir = os.path.join(model_state_dir, model_name)
        
        for model_state in reversed(os.listdir(model_dir)):
            path = os.path.join(model_dir, model_state)
            matches = re.match(".*epoch_(\\d+).pth", path)

            if matches:
                epoch_number = matches.group(1)

                yield model_name, int(epoch_number), path

                how_many += 1

                if how_many >= max:
                    break

# %%
import time

# Columns produced by the mAP metric
mAP_columns = [
    'map',
    'map_small',
    'map_medium',
    'map_large',
    'mar_1',
    'mar_10',
    'mar_100',
    'mar_small',
    'mar_medium',
    'mar_large',
    'map_50',
    'map_75',
    'map_per_class',
    'mar_100_per_class']

columns=['model', 'loss', 'epoch', 'path', *mAP_columns]

# %%
df = pd.DataFrame(columns=columns)

started_at = time.time()

for model_name, epoch_number, path in enumerate_states(MODEL_STATE_DIR):
    loaded = torch.load(path)
    # add to the dataframe
    row = {
        'model': model_name,
        'epoch': epoch_number,
        'loss': loaded['loss'],
        'path': path
    }

    df = add(df, row)

    if len(df) % 20 == 0:
        print(
            f'Processed {len(df)} states. Current speed: {len(df) / (time.time() - started_at)} states per second')


df = df.sort_values(by=['loss'])
# Out:
# Processed 20 states. Current speed: 1.3722946014623791 states per second

# %%
class ColorPerValue:
	"""Used to assign color to values"""
	def __init__(self):
		self._colors = ['red', 'orange', 'lightblue', 'lightgreen', 'white']
		self._values = []

	def get_color(self, value: Any):
		"""Returns the color for the value"""
		if value not in self._values:
			self._values.append(value)
		
		color_idx = self._values.index(value)		

		return self._colors[color_idx]

# %%
model_color = ColorPerValue()
# group by model and show the lowest losses
top_states = df.groupby('model').head(1).sort_values(by=['model', 'loss'])
# conditional coloring the first column based on name
top_states.style.apply(lambda x: [f'color: {model_color.get_color(x.model)}' for i in x], axis=1)
# Out:
# <style type="text/css">
# #T_e6aa5_row0_col0, #T_e6aa5_row0_col1, #T_e6aa5_row0_col2, #T_e6aa5_row0_col3, #T_e6aa5_row0_col4, #T_e6aa5_row0_col5, #T_e6aa5_row0_col6, #T_e6aa5_row0_col7, #T_e6aa5_row0_col8, #T_e6aa5_row0_col9, #T_e6aa5_row0_col10, #T_e6aa5_row0_col11, #T_e6aa5_row0_col12, #T_e6aa5_row0_col13, #T_e6aa5_row0_col14, #T_e6aa5_row0_col15, #T_e6aa5_row0_col16, #T_e6aa5_row0_col17 {
#   color: red;
# }
# #T_e6aa5_row1_col0, #T_e6aa5_row1_col1, #T_e6aa5_row1_col2, #T_e6aa5_row1_col3, #T_e6aa5_row1_col4, #T_e6aa5_row1_col5, #T_e6aa5_row1_col6, #T_e6aa5_row1_col7, #T_e6aa5_row1_col8, #T_e6aa5_row1_col9, #T_e6aa5_row1_col10, #T_e6aa5_row1_col11, #T_e6aa5_row1_col12, #T_e6aa5_row1_col13, #T_e6aa5_row1_col14, #T_e6aa5_row1_col15, #T_e6aa5_row1_col16, #T_e6aa5_row1_col17 {
#   color: orange;
# }
# #T_e6aa5_row2_col0, #T_e6aa5_row2_col1, #T_e6aa5_row2_col2, #T_e6aa5_row2_col3, #T_e6aa5_row2_col4, #T_e6aa5_row2_col5, #T_e6aa5_row2_col6, #T_e6aa5_row2_col7, #T_e6aa5_row2_col8, #T_e6aa5_row2_col9, #T_e6aa5_row2_col10, #T_e6aa5_row2_col11, #T_e6aa5_row2_col12, #T_e6aa5_row2_col13, #T_e6aa5_row2_col14, #T_e6aa5_row2_col15, #T_e6aa5_row2_col16, #T_e6aa5_row2_col17 {
#   color: lightblue;
# }
# #T_e6aa5_row3_col0, #T_e6aa5_row3_col1, #T_e6aa5_row3_col2, #T_e6aa5_row3_col3, #T_e6aa5_row3_col4, #T_e6aa5_row3_col5, #T_e6aa5_row3_col6, #T_e6aa5_row3_col7, #T_e6aa5_row3_col8, #T_e6aa5_row3_col9, #T_e6aa5_row3_col10, #T_e6aa5_row3_col11, #T_e6aa5_row3_col12, #T_e6aa5_row3_col13, #T_e6aa5_row3_col14, #T_e6aa5_row3_col15, #T_e6aa5_row3_col16, #T_e6aa5_row3_col17 {
#   color: lightgreen;
# }
# </style>
# <table id="T_e6aa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6aa5_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_e6aa5_level0_col1" class="col_heading level0 col1" >loss</th>
#       <th id="T_e6aa5_level0_col2" class="col_heading level0 col2" >epoch</th>
#       <th id="T_e6aa5_level0_col3" class="col_heading level0 col3" >path</th>
#       <th id="T_e6aa5_level0_col4" class="col_heading level0 col4" >map</th>
#       <th id="T_e6aa5_level0_col5" class="col_heading level0 col5" >map_small</th>
#       <th id="T_e6aa5_level0_col6" class="col_heading level0 col6" >map_medium</th>
#       <th id="T_e6aa5_level0_col7" class="col_heading level0 col7" >map_large</th>
#       <th id="T_e6aa5_level0_col8" class="col_heading level0 col8" >mar_1</th>
#       <th id="T_e6aa5_level0_col9" class="col_heading level0 col9" >mar_10</th>
#       <th id="T_e6aa5_level0_col10" class="col_heading level0 col10" >mar_100</th>
#       <th id="T_e6aa5_level0_col11" class="col_heading level0 col11" >mar_small</th>
#       <th id="T_e6aa5_level0_col12" class="col_heading level0 col12" >mar_medium</th>
#       <th id="T_e6aa5_level0_col13" class="col_heading level0 col13" >mar_large</th>
#       <th id="T_e6aa5_level0_col14" class="col_heading level0 col14" >map_50</th>
#       <th id="T_e6aa5_level0_col15" class="col_heading level0 col15" >map_75</th>
#       <th id="T_e6aa5_level0_col16" class="col_heading level0 col16" >map_per_class</th>
#       <th id="T_e6aa5_level0_col17" class="col_heading level0 col17" >mar_100_per_class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6aa5_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e6aa5_row0_col0" class="data row0 col0" >fasterrcnn_resnet50_fpn-pretrained</td>
#       <td id="T_e6aa5_row0_col1" class="data row0 col1" >0.296820</td>
#       <td id="T_e6aa5_row0_col2" class="data row0 col2" >46</td>
#       <td id="T_e6aa5_row0_col3" class="data row0 col3" >../model_state\fasterrcnn_resnet50_fpn-pretrained\epoch_046.pth</td>
#       <td id="T_e6aa5_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_e6aa5_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_e6aa5_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_e6aa5_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_e6aa5_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_e6aa5_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_e6aa5_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_e6aa5_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_e6aa5_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_e6aa5_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_e6aa5_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_e6aa5_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_e6aa5_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_e6aa5_row0_col17" class="data row0 col17" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e6aa5_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_e6aa5_row1_col0" class="data row1 col0" >fasterrcnn_resnet50_fpn-untrained</td>
#       <td id="T_e6aa5_row1_col1" class="data row1 col1" >0.353208</td>
#       <td id="T_e6aa5_row1_col2" class="data row1 col2" >42</td>
#       <td id="T_e6aa5_row1_col3" class="data row1 col3" >../model_state\fasterrcnn_resnet50_fpn-untrained\epoch_042.pth</td>
#       <td id="T_e6aa5_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_e6aa5_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_e6aa5_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_e6aa5_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_e6aa5_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_e6aa5_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_e6aa5_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_e6aa5_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_e6aa5_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_e6aa5_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_e6aa5_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_e6aa5_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_e6aa5_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_e6aa5_row1_col17" class="data row1 col17" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e6aa5_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_e6aa5_row2_col0" class="data row2 col0" >fasterrcnn_resnet50_fpn_v2-pretrained</td>
#       <td id="T_e6aa5_row2_col1" class="data row2 col1" >0.262157</td>
#       <td id="T_e6aa5_row2_col2" class="data row2 col2" >45</td>
#       <td id="T_e6aa5_row2_col3" class="data row2 col3" >../model_state\fasterrcnn_resnet50_fpn_v2-pretrained\epoch_045.pth</td>
#       <td id="T_e6aa5_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_e6aa5_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_e6aa5_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_e6aa5_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_e6aa5_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_e6aa5_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_e6aa5_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_e6aa5_row2_col11" class="data row2 col11" >nan</td>
#       <td id="T_e6aa5_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_e6aa5_row2_col13" class="data row2 col13" >nan</td>
#       <td id="T_e6aa5_row2_col14" class="data row2 col14" >nan</td>
#       <td id="T_e6aa5_row2_col15" class="data row2 col15" >nan</td>
#       <td id="T_e6aa5_row2_col16" class="data row2 col16" >nan</td>
#       <td id="T_e6aa5_row2_col17" class="data row2 col17" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e6aa5_level0_row3" class="row_heading level0 row3" >25</th>
#       <td id="T_e6aa5_row3_col0" class="data row3 col0" >fasterrcnn_resnet50_fpn_v2-untrained</td>
#       <td id="T_e6aa5_row3_col1" class="data row3 col1" >0.693418</td>
#       <td id="T_e6aa5_row3_col2" class="data row3 col2" >48</td>
#       <td id="T_e6aa5_row3_col3" class="data row3 col3" >../model_state\fasterrcnn_resnet50_fpn_v2-untrained\epoch_048.pth</td>
#       <td id="T_e6aa5_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_e6aa5_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_e6aa5_row3_col6" class="data r

# %%
from money_counter import data, engine, utils, coco_eval

version_manager = money_counter.models.VersionManager(MODEL_STATE_DIR)
device = utils.get_device()

_, data_loader_test = money_counter.data.get_data_loaders(COINS_DATASET_PATH, batch_size=4)

coco_evaluator = None
# Out:
# INFO:money_counter.data:Train dataset size: 487
# INFO:money_counter.data:Test dataset size: 121

# %%
mAP = MeanAveragePrecision(num_classes=constants.NUM_CLASSES, iou_thresholds=[0.5, 0.75], max_detection_threshold=100, class_labels=constants.CLASSES)

# %%
from IPython import display

mAP.reset()

models_progress = display.ProgressBar(len(top_states))
models_progress.display()

images_progress = display.ProgressBar(len(data_loader_test))
images_progress.display()

# Let's calculate the mAP for the top states
for idx, row in top_states.iterrows():
    model_name = row['model']
    model = models.get_model(model_name).to(device)
    epoch_number = row['epoch']
    path = row['path']

    version_manager.load_model(
        model_name, model, epoch=row['epoch'], map_location=device)

    # Put the model in evaluation mode
    model.eval()

    with torch.no_grad():
        logging.info(f'Calculating mAP for {model_name} at epoch {epoch_number}...')

        images_progress.progress = 0
        images_progress.update()

        for (images, targets) in data_loader_test:
            # Move images to the device
            images = list(image.to(device) for image in images)
            # Move target to the device
            targets = [{k: v.to(device) for k, v in t.items()}
                       for t in targets]
            # update the progress 
            images_progress.progress += 1
            
            # Evaluate the model on the test set
            predictions = model(images)            

            # Update the mAP metric
            mAP.update(predictions, targets)

    # Update the mAP column in the row
    computed = mAP.compute()

    for key in computed:
        top_states.at[idx, key] = computed[key].item()

    models_progress.progress += 1
    models_progress.update()
# Out:
# [============================================================] 4/4
# [================================================================================================================================================================================================================================================] 124/31
# INFO:money_counter.models:Loaded model state from ../model_state/fasterrcnn_resnet50_fpn-pretrained/epoch_046.pth
# INFO:root:Calculating mAP for fasterrcnn_resnet50_fpn-pretrained at epoch 46...
# INFO:money_counter.models:Loaded model state from ../model_state/fasterrcnn_resnet50_fpn-untrained/epoch_042.pth
# INFO:root:Calculating mAP for fasterrcnn_resnet50_fpn-untrained at epoch 42...
# INFO:money_counter.models:Loaded model state from ../model_state/fasterrcnn_resnet50_fpn_v2-pretrained/epoch_045.pth
# INFO:root:Calculating mAP for fasterrcnn_resnet50_fpn_v2-pretrained at epoch 45...
# INFO:money_counter.models:Loaded model state from ../model_state/fasterrcnn_resnet50_fpn_v2-untrained/epoch_048.pth
# INFO:root:Calculating mAP for fasterrcnn_resnet50_fpn_v2-untrained at epoch 48...

# %%
top_states.sort_values(by=['map'], ascending=False)
# Out:
#                                     model      loss  epoch  \
# 3      fasterrcnn_resnet50_fpn-pretrained  0.296820     46
# 15      fasterrcnn_resnet50_fpn-untrained  0.353208     42
# 20  fasterrcnn_resnet50_fpn_v2-pretrained  0.262157     45
# 25   fasterrcnn_resnet50_fpn_v2-untrained  0.693418     48
#
#                                                  path       map  map_small  \
# 3   ../model_state\fasterrcnn_resnet50_fpn-pretrai...  0.773670       -1.0
# 15  ../model_state\fasterrcnn_resnet50_fpn-untrain...  0.766483       -1.0
# 20  ../model_state\fasterrcnn_resnet50_fpn_v2-pret...  0.757615       -1.0
# 25  ../model_state\fasterrcnn_resnet50_fpn_v2-untr...  0.709994       -1.0
#
#     map_medium  map_large     mar_1    mar_10   mar_100  mar_small  \
# 3         -1.0   0.773670  0.245821  0.822974  0.872282       -1.0
# 15        -1.0   0.766490  0.246589  0.838961  0.896990       -1.0
# 20        -1.0   0.757622  0.243761  0.836541  0.895520       -1.0
# 25        -1.0   0.710001  0.228269  0.799575  0.867934       -1.0
#
#     mar_medium  mar_large    map_50    map_75  map_per_class  \
# 3         -1.0   0.872282  0.779582  0.767758           -1.0
# 15        -1.0   0.896990  0.773621  0.759344           -1.0
# 20        -1.0   0.895520  0.764216  0.751013           -1.0
# 25        -1.0   0.867934  0.718844  0.701144           -1.0
#
#     mar_100_per_class
# 3                -1.0
# 15               -1.0
# 20               -1.0
# 25               -1.0
